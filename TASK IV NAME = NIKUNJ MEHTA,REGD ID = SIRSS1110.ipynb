# %%
import pandas as pd
import numpy as np
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv('data.csv')

# %%
data.head(5)
# Out:
#     ad_id reporting_start reporting_end  campaign_id  fb_campaign_id    age  \
# 0  708746      17/08/2017    17/08/2017          916          103916  30-34
# 1  708749      17/08/2017    17/08/2017          916          103917  30-34
# 2  708771      17/08/2017    17/08/2017          916          103920  30-34
# 3  708815      30/08/2017    30/08/2017          916          103928  30-34
# 4  708818      17/08/2017    17/08/2017          916          103928  30-34
#
#   gender  interest1  interest2  interest3  impressions  clicks  spent  \
# 0      M         15         17         17         7350       1   1.43
# 1      M         16         19         21        17861       2   1.82
# 2      M         20         25         22          693       0   0.00
# 3      M         28         32         32         4259       1   1.25
# 4      M         28         33         32         4133       1   1.29
#
#    total_conversion  approved_conversion
# 0                 2                    1
# ...

# %%
data.tail()
# Out:
#        ad_id reporting_start reporting_end  campaign_id  fb_campaign_id  \
# 756  1121585      20/08/2017    20/08/2017         1178          144621
# 757  1121589      20/08/2017    20/08/2017         1178          144622
# 758  1121590      20/08/2017    20/08/2017         1178          144622
# 759  1121592      20/08/2017    20/08/2017         1178          144622
# 760  1121593      26/08/2017    26/08/2017         1178          144622
#
#        age gender  interest1  interest2  interest3  impressions  clicks  \
# 756  40-44      M         66         72         68         9773       1
# 757  45-49      M         10         16         11       464036      77
# 758  45-49      M         10         16         15       478480      75
# 759  45-49      M         10         14         11       428812      66
# 760  45-49      M         10         16         16      1177535     221
#
#           spent  total_conversion  approved_conversion
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                761 non-null    int64
#  1   reporting_start      761 non-null    object
#  2   reporting_end        761 non-null    object
#  3   campaign_id          761 non-null    int64
#  4   fb_campaign_id       761 non-null    int64
#  5   age                  761 non-null    object
#  6   gender               761 non-null    object
#  7   interest1            761 non-null    int64
#  8   interest2            761 non-null    int64
#  9   interest3            761 non-null    int64
#  10  impressions          761 non-null    int64
#  11  clicks               761 non-null    int64
#  12  spent                761 non-null    float64
#  13  total_conversion     761 non-null    int64
#  14  approved_conversion  761 non-null    int64
# ...

# %%
data['clicks'].describe()
# Out:
# count    761.000000
# mean      15.340342
# std       32.715738
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%       14.000000
# max      340.000000
# Name: clicks, dtype: float64

# %%
data['clicks'].min()
# Out:
# 0

# %%
data['clicks'].max()
# Out:
# 340

# %%
data['clicks'].mean()
# Out:
# 15.340341655716163

# %%
data['clicks'].std()
# Out:
# 32.7157384367534

# %%
plt.scatter(data.clicks,data.campaign_id)
plt.show()

# %%
sns.pairplot(data=data,vars=['clicks','campaign_id'])
plt.show()

# %%
plt.hist(data['clicks'])
plt.figure(figsize=(4,4))

# %%
data.groupby('campaign_id')['clicks'].mean().plot.bar()
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(data['campaign_id'],data['clicks'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='campaign_id', ylabel='clicks'>

# %%
corr = data.corr()

sns.heatmap(corr,annot= True,cmap='YlOrBr', 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>
